# %% [markdown]
# # Tanpopo1 表面付着物 VGG16 CrossValidation

# %%
# Google Colab マウント
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive
import os
os.chdir('/content/drive/MyDrive/Tanpopo')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import torch.utils.data as data

import matplotlib.pyplot as plt
import glob
import time
import copy
from PIL import Image

plt.ion()
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
#画像サイズがが704x480 #88x60
img_size = 224

#class_names = ['1Sputter', '2Fiber', '3Block', '4Bar', '5AGFragment']
class_num = 5

# 標準化
mean = (0.5, 0.5, 0.5)
std = (0.5, 0.5, 0.5)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#torch.set_default_tensor_type('torch.cuda.FloatTensor')

# %%
batch_size =  "16" #@param[8, 16, 32, 64, 128, 256]
batch_size = int(batch_size)

epochs = "25" #@param[5, 8, 10, 15, 20, 22, 25, 27, 29, 30, 31, 32, 33, 35, 45, 60, 120]
epochs = int(epochs)

# %% [markdown]
# ### 関数、クラスの定義

# %%
import random
from sklearn.model_selection import train_test_split
def make_filepath_list(folderpath, phase='train'):
    """
    ファイルのパスを格納したリストを返す
    """
    # .DS_Storeが最初に読み込まれる
    file_list = []
    files_list = []
    class_names = []

    for index, top_dir in enumerate(sorted(os.listdir(folderpath))):
        file_dir = os.path.join(folderpath, top_dir)
        file_list = glob.glob(file_dir + '/*bmp')

        if top_dir != '.DS_Store':
            class_names.append(top_dir)
            files_list += [os.path.join(folderpath, top_dir, file).replace('\\', '/') for file in file_list]
                                                            
    return files_list, class_names

# %%
class ImageTransform(object):
    """
    画像の前処理
    """
    def __init__(self, resize, mean, std):
        self.data_transform = {
            'train': transforms.Compose([
                # データオグメンテーション, 前処理
                transforms.Resize(256), # リサイズ
                transforms.CenterCrop(resize), # 切り取り
                transforms.RandomRotation(45), # ランタムに回転
                transforms.ColorJitter(), # ランダムに明るさ、コントラスト、彩度、色相を変化
                transforms.RandomHorizontalFlip(), # ランダムに左右(水平)反転
                transforms.RandomVerticalFlip(), # ランダムに上下(垂直)反転
                transforms.ToTensor(),
                transforms.Normalize(mean, std), # zcaと交換？
                # ZCA whitening追加する
            ]),
            'valid': transforms.Compose([
                transforms.Resize(256),
                transforms.CenterCrop(resize),
                transforms.ToTensor(),
                transforms.Normalize(mean, std),
            ]),
            'test': transforms.Compose([
                transforms.Resize(256),
                transforms.CenterCrop(resize),
                transforms.ToTensor(),
                transforms.Normalize(mean, std),
            ])
        }

    def __call__(self, img, phase='train'):
        return self.data_transform[phase](img)

# %%
from torchvision.io import read_image

class SurfaceObjectDataset(data.Dataset):
    """
    表面付着物のDatasetクラス
    PyTorchのDatasetクラスを継承
    """
    def __init__(self, file_list, classes, transform=None, phase='train'):
        #super().__init__()
        self.file_list = file_list
        self.transform = transform
        self.classes = classes
        self.phase = phase

        self.img = None
        self.label = None

    def __len__(self):
        """
        画像の枚数を返す
        """
        return len(self.file_list)

    def __getitem__(self, index):
        """
        前処理した画像データのTensor形式のデータとラベルを取得
        """
        # 指定したindexの画像を読み込む
        img_path = self.file_list[index]
        img = Image.open(img_path)

        # 画像ラベルをファイル名から抜き出す
        label = self.file_list[index].split('/')[6][:11]

        # ラベル名を数値に変換
        label = self.classes.index(label)

        # 画像の前処理を実施
        if self.transform is not None:
            img_transformed = self.transform(img, self.phase)
            
        return img_transformed, label

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))

        # 各エポックには訓練フェーズと検証フェーズがあります
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # モデルを訓練モードに設定します
            else:
                model.eval()   # モードを評価するモデルを設定します

            running_loss = 0.0
            running_corrects = 0

            # データをイレテートします
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # パラメータの勾配をゼロにします
                optimizer.zero_grad()

                # 順伝播
                # 訓練の時だけ、履歴を保持します
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # 訓練の時だけ逆伝播＋オプティマイズを行います
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # 損失を計算します
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            # if phase == 'train':
            #     scheduler.step()

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print(' {} Loss: {:.4f} Acc: {:.4f} '.format(
                phase, epoch_loss, epoch_acc), end='\t')

            # モデルをディープ・コピーします
            if phase == 'valid' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # ベストモデルの重みをロードします
    model.load_state_dict(best_model_wts)
    return model, best_acc

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

#正解
def class_accuracy(label, conf_mat):
    return (conf_mat[label][label] + (np.sum(conf_mat) - (np.sum(conf_mat[:, label])+np.sum(conf_mat[label])-conf_mat[label][label]))) / np.sum(conf_mat)
    
#精度(適合率)
def class_precision(label, conf_mat):
    return conf_mat[label][label] / np.sum(conf_mat[label])

#再現率
def class_recall(label, conf_mat):
    return conf_mat[label][label] / np.sum(conf_mat[:, label])

# テスト結果を返す
def test_model(model, test_dataloaders):
    labels_sum = None
    predicted_sum = None

    with torch.no_grad():
        for data in test_dataloaders:
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)

            #outputs = nn.Softmax(dim=1)(outputs)

            _, predicted = torch.max(outputs, 1)

            if labels_sum is None:
                labels_sum = labels
                predicted_sum = predicted
            else:
                labels_sum = torch.cat([labels_sum, labels], dim=0)
                predicted_sum = torch.cat([predicted_sum, predicted], dim=0)

    #混同行列
    labels_sum = labels_sum.cpu()
    predicted_sum = predicted_sum.cpu()
    conf_mat = None
    Accuracy = []
    Precision = []
    Recall = []

    conf_mat = confusion_matrix(labels_sum, predicted_sum)

    for i in range(class_num):
        Accuracy = np.append(Accuracy, class_accuracy(i, conf_mat)*100)
        Precision = np.append(Precision, class_precision(i, conf_mat)*100)
        Recall = np.append(Recall, class_recall(i, conf_mat)*100)

    return conf_mat, Accuracy, Precision, Recall

# %% [markdown]
# ### モデルの作成

# %%
model_vgg16 = models.vgg16(pretrained=True) # VGG16学習済みの重みを使用

# VGG16 の最後の層
model_vgg16.classifier[6] = nn.Linear(in_features=4096, out_features=5)
#print(model_vgg16)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# 転移学習で学習させるパラメータを、変数params_to_updateに格納
params_to_update = []

# まず全パラメータを勾配計算Falseにする
for name, param in model_vgg16.named_parameters():
    param.requires_grad = False

for name, param in model_vgg16.classifier.named_parameters(): # 全結合層のみパラメータ更新
    param.requires_grad = True
    params_to_update.append(param)

optimizer = optim.AdamW(params_to_update, lr=0.001, weight_decay=0.01)

criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ### 学習

# %%
from torch.utils.data.dataset import Subset
from sklearn.model_selection import KFold
from  torch.utils.data import Dataset

# 訓練、検証データへのファイルパスを格納したリストを取得
train_file_list, class_names = make_filepath_list('/content/drive/MyDrive/Tanpopo/TrainingData11', 'train')
#print('train_file_list: ', train_file_list)
#print('class_names: ', class_names)
class_num = len(class_names) # 5

dataset = SurfaceObjectDataset(
        file_list = train_file_list, classes = class_names,
        transform = ImageTransform(img_size, mean, std),
        phase = 'train')

# テストデータ
test_file_list, class_names_test = make_filepath_list('/content/drive/MyDrive/Tanpopo/TestData11', 'test')
#print('test_file_list : ', test_file_list)
#print('class_names_test : ', class_names_test)

# Datasetの作成
test_dataset = SurfaceObjectDataset(
    file_list = test_file_list, classes = class_names_test,
    transform = ImageTransform(img_size, mean, std),
    phase = 'test')
# Dataloaderの作成
test_dataloader = data.DataLoader(
    test_dataset, batch_size = int(batch_size/2), shuffle=False)
dataloaders_dict = {'test': test_dataloader}


# K-Fold 交差検証 
kf = KFold(n_splits=5, shuffle=True, random_state=1) # 5回検証

scores = []
test_accuracy = []
test_precision = []
test_recall = []
conf_mat = []

PATH = '/content/drive/MyDrive/Tanpopo/model_vgg16_weights.pth'
model_vgg16.load_state_dict(torch.load(PATH)) # 学習前: 前回の重みを使う

for _fold, (train_index, valid_index) in enumerate(kf.split(train_file_list)):
    # Datasetの作成
    train_dataset = Subset(dataset, train_index)
    valid_dataset = Subset(dataset, valid_index)
    # Dataloaderの作成
    train_dataloader = data.DataLoader(
        train_dataset, batch_size = batch_size, shuffle=True)
    valid_dataloader = data.DataLoader(
        valid_dataset, batch_size = int(batch_size/2), shuffle=False)
    
    dataloaders_dict['train'] = train_dataloader
    dataloaders_dict['valid'] = valid_dataloader

    print('-'*5, end='')
    print(_fold+1, end='')
    print('-'*5)
    model_vgg16 = model_vgg16.to(device)
    model_vgg16, score = train_model(model_vgg16, dataloaders_dict, criterion, optimizer, num_epochs=epochs)
    scores.append(score.to('cpu'))

    conf, test_acc, test_prec, test_rec = test_model(model_vgg16, dataloaders_dict['test'])
    test_accuracy.append(test_acc)
    test_precision.append(test_prec)
    test_recall.append(test_rec)
    conf_mat.append(conf)
# Out:
# -----1-----
# Epoch 0/24
#  train Loss: 0.8215 Acc: 0.7245 	 valid Loss: 0.5685 Acc: 0.7551
# Epoch 1/24
#  train Loss: 0.8625 Acc: 0.7398 	 valid Loss: 0.2831 Acc: 0.8776
# Epoch 2/24
#  train Loss: 0.7654 Acc: 0.7653 	 valid Loss: 0.2998 Acc: 0.9388
# Epoch 3/24
#  train Loss: 0.5935 Acc: 0.8367 	 valid Loss: 0.4812 Acc: 0.8980
# Epoch 4/24
#  train Loss: 0.8335 Acc: 0.7653 	 valid Loss: 0.6938 Acc: 0.8367
# Epoch 5/24
#  train Loss: 1.0197 Acc: 0.7653 	 valid Loss: 0.5990 Acc: 0.7755
# Epoch 6/24
#  train Loss: 1.0428 Acc: 0.7806 	 valid Loss: 0.4370 Acc: 0.8163
# Epoch 7/24
#  train Loss: 0.7466 Acc: 0.8214 	 valid Loss: 0.4602 Acc: 0.8776
# Epoch 8/24
#  train Loss: 0.7481 Acc: 0.7857 	 valid Loss: 0.5719 Acc: 0.8367
# Epoch 9/24
#  train Loss: 0.8334 Acc: 0.7704 	 valid Loss: 0.4382 Acc: 0.8571
# Epoch 10/24
#  train Loss: 0.5956 Acc: 0.8265 	 valid Loss: 0.3611 Acc: 0.8980
# Epoch 11/24
#  train Loss: 0.5375 Acc: 0.8571 	 valid Loss: 0.4379 Acc: 0.8163
# Epoch 12/24
#  train Loss: 1.0016 Acc: 0.7959 	 valid Loss: 0.1978 Acc: 0.9184
# Epoch 13/24
#  train Loss: 0.7477 Acc: 0.8163 	 valid Loss: 1.0351 Acc: 0.8367
# Epoch 14/24
#  train Loss: 0.9944 Acc: 0.7857 	 valid Loss: 0.5612 Acc: 0.8367
# Epoch 15/24
#  train Loss: 0.8893 Acc: 0.7908 	 valid Loss: 0.4027 Acc: 0.8776
# Epoch 16/24
#  train Loss: 0.6559 Acc: 0.8316 	 valid Loss: 0.5410 Acc: 0.8163
# Epoch 17/24
#  train Loss: 0.6208 Acc: 0.8316 	 valid Loss: 0.2662 Acc: 0.8980
# Epoch 18/24
#  train Loss: 0.7885 Acc: 0.8367 	 valid Loss: 0.3268 Acc: 0.9184
# Epoch 19/24
#  train Loss: 1.3982 Acc: 0.7500 	 valid Loss: 0.4853 Acc: 0.8980
# Epoch 20/24
#  train Loss: 0.8965 Acc: 0.8214 	 valid Loss: 0.3175 Acc: 0.8776
# Epoch 21/24
#  train Loss: 0.9975 Acc: 0.7908 	 valid Loss: 0.7000 Acc: 0.8163
# Epoch 22/24
#  train Loss: 1.0749 Acc: 0.7704 	 valid Loss: 1.1964 Acc: 0.7551
# Epoch 23/24
#  train Loss: 1.3356 Acc: 0.7194 	 valid Loss: 0.4586 Acc: 0.8980
# Epoch 24/24
#  train Loss: 1.3015 Acc: 0.7857 	 valid Loss: 0.4786 Acc: 0.8163
# Training complete in 1m 35s
# Best val Acc: 0.938776
# -----2-----
# Epoch 0/24
#  train Loss: 0.6350 Acc: 0.7755 	 valid Loss: 0.2325 Acc: 0.9796
# Epoch 1/24
#  train Loss: 0.9700 Acc: 0.7500 	 valid Loss: 1.2243 Acc: 0.5918
# Epoch 2/24
#  train Loss: 1.1747 Acc: 0.6990 	 valid Loss: 0.3388 Acc: 0.8571
# Epoch 3/24
#  train Loss: 0.8923 Acc: 0.8367 	 valid Loss: 0.6547 Acc: 0.8776
# Epoch 4/24
#  train Loss: 0.7876 Acc: 0.7857 	 valid Loss: 0.4011 Acc: 0.8980
# Epoch 5/24
#  train Loss: 0.7687 Acc: 0.7755 	 valid Loss: 0.3169 Acc: 0.8980
# Epoch 6/24
#  train Loss: 0.9288 Acc: 0.7296 	 valid Loss: 0.4738 Acc: 0.8571
# Epoch 7/24
#  train Loss: 0.6420 Acc: 0.7908 	 valid Loss: 0.3274 Acc: 0.8571
# Epoch 8/24
#  train Loss: 0.5476 Acc: 0.8316 	 valid Loss: 0.4865 Acc: 0.8980
# Epoch 9/24
#  train Loss: 0.8253 Acc: 0.8265 	 valid Loss: 0.2244 Acc: 0.8980
# Epoch 10/24
#  train Loss: 0.6483 Acc: 0.8112 	 valid Loss: 0.6286 Acc: 0.8367
# Epoch 11/24
#  train Loss: 0.7403 Acc: 0.7908 	 valid Loss: 0.5594 Acc: 0.8571
# Epoch 12/24
#  train Loss: 0.7924 Acc: 0.8316 	 valid Loss: 0.4323 Acc: 0.8980
# Epoch 13/24
#  train Loss: 0.6973 Acc: 0.8571 	 valid Loss: 0.3879 Acc: 0.9184
# Epoch 14/24
#  train Loss: 0.5666 Acc: 0.8316 	 valid Loss: 0.2930 Acc: 0.8980
# Epoch 15/24
#  train Loss: 0.7708 Acc: 0.7704 	 valid Loss: 0.5093 Acc: 0.8980
# Epoch 16/24
#  train Loss: 0.8818 Acc: 0.7755 	 valid Loss: 0.3435 Acc: 0.9388
# Epoch 17/24
#  train Loss: 0.9096 Acc: 0.7755 	 valid Loss: 0.2740 Acc: 0.8571
# Epoch 18/24
#  train Loss: 0.8884 Acc: 0.7704 	 valid Loss: 0.4181 Acc: 0.9388
# Epoch 19/24
#  train Loss: 0.6881 Acc: 0.8112 	 valid Loss: 0.3302 Acc: 0.8571
# Epoch 20/24
#  train Loss: 0.8298 Acc: 0.7959 	 valid Loss: 0.6618 Acc: 0.8571
# Epoch 21/24
#  train Loss: 0.7063 Acc: 0.8061 	 valid Loss: 0.1647 Acc: 0.9796
# Epoch 22/24
#  train Loss: 0.9969 Acc: 0.7704 	 valid Loss: 0.3554 Acc: 0.8367
# Epoch 23/24
#  train Loss: 1.0425 Acc: 0.7296 	 valid Loss: 0.8877 Acc: 0.8367
# Epoch 24/24
#  train Loss: 0.8889 Acc: 0.7755 	 valid Loss: 0.4582 Acc: 0.8571
# Training complete in 1m 35s
# Best val Acc: 0.979592
# -----3-----
# Epoch 0/24
#  train Loss: 0.6372 Acc: 0.8163 	 valid Loss: 0.4428 Acc: 0.8367
# Epoch 1/24
#  train Loss: 0.8074 Acc: 0.8214 	 valid Loss: 0.7762 Acc: 0.7551
# Epoch 2/24
#  train Loss: 0.8624 Acc: 0.7704 	 valid Loss: 0.4977 Acc: 0.8367
# Epoch 3/24
#  train Loss: 0.7649 Acc: 0.8265 	 valid Loss: 0.2940 Acc: 0.8776
# Epoch 4/24
#  train Loss: 0.7786 Acc: 0.8112 	 valid Loss: 0.4318 Acc: 0.8571
# Epoch 5/24
#  train Loss: 0.6383 Acc: 0.8163 	 valid Loss: 0.7092 Acc: 0.7551
# Epoch 6/24
#  train Loss: 0.7149 Acc: 0.8265 	 valid Loss: 0.8307 Acc: 0.7347
# Epoch 7/24
#  train Loss: 0.7403 Acc: 0.7755 	 valid Loss: 0.3644 Acc: 0.7755
# Epoch 8/24
#  train Loss: 0.5930 Acc: 0.8316 	 valid Loss: 0.7969 Acc: 0.7551
# Epoch 9/24
#  train Loss: 0.8381 Acc: 0.8214 	 valid Loss: 0.4957 Acc: 0.7959
# Epoch 10/24
#  train Loss: 0.6618 Acc: 0.8214 	 valid Loss: 0.8287 Acc: 0.7959
# Epoch 11/24
#  train Loss: 0.7422 Acc: 0.8010 	 valid Loss: 0.7328 Acc: 0.7959
# Epoch 12/24
#  train Loss: 0.5906 Acc: 0.8622 	 valid Loss: 0.9822 Acc: 0.7551
# Epoch 13/24
#  train Loss: 1.0006 Acc: 0.8112 	 valid Loss: 1.1643 Acc: 0.6531
# Epoch 14/24
#  train Loss: 0.9844 Acc: 0.7857 	 valid Loss: 0.5226 Acc: 0.8367
# Epoch 15/24
#  train Loss: 0.6925 Acc: 0.8265 	 valid Loss: 1.3221 Acc: 0.7347
# Epoch 16/24
#  train Loss: 0.8423 Acc: 0.8061 	 valid Loss: 0.6405 Acc: 0.8367
# Epoch 17/24
#  train Loss: 0.4529 Acc: 0.8469 	 valid Loss: 0.6701 Acc: 0.7143
# Epoch 18/24
#  train Loss: 0.6095 Acc: 0.8418 	 valid Loss: 0.7795 Acc: 0.7347
# Epoch 19/24
#  train Loss: 0.7270 Acc: 0.8112 	 valid Loss: 0.7645 Acc: 0.7143
# Epoch 20/24
#  train Loss: 0.5821 Acc: 0.8673 	 valid Loss: 0.6974 Acc: 0.7755
# Epoch 21/24
#  train Loss: 0.6385 Acc: 0.8061 	 valid Loss: 0.4763 Acc: 0.7959
# Epoch 22/24
#  train Loss: 0.7601 Acc: 0.7908 	 valid Loss: 0.5442 Acc: 0.8367
# Epoch 23/24
#  train Loss: 0.6133 Acc: 0.8316 	 valid Loss: 0.6478 Acc: 0.7959
# Epoch 24/24
#  train Loss: 0.8863 Acc: 0.7857 	 valid Loss: 0.8309 Acc: 0.7551
# Training complete in 1m 35s
# Best val Acc: 0.877551
# -----4-----
# Epoch 0/24
#  train Loss: 0.6608 Acc: 0.8163 	 valid Loss: 0.2427 Acc: 0.9184
# Epoch 1/24
#  train Loss: 0.7778 Acc: 0.8061 	 valid Loss: 0.2032 Acc: 0.9184
# Epoch 2/24
#  train Loss: 0.6357 Acc: 0.8061 	 valid Loss: 0.2962 Acc: 0.8571
# Epoch 3/24
#  train Loss: 0.8708 Acc: 0.7908 	 valid Loss: 0.2843 Acc: 0.9592
# Epoch 4/24
#  train Loss: 0.6233 Acc: 0.7806 	 valid Loss: 0.2556 Acc: 0.9184
# Epoch 5/24
#  train Loss: 0.7830 Acc: 0.8010 	 valid Loss: 0.2185 Acc: 0.8776
# Epoch 6/24
#  train Loss: 0.6726 Acc: 0.8061 	 valid Loss: 0.3463 Acc: 0.8776
# Epoch 7/24
#  train Loss: 0.6463 Acc: 0.8112 	 valid Loss: 0.2768 Acc: 0.8776
# Epoch 8/24
#  train Loss: 0.6165 Acc: 0.7959 	 valid Loss: 0.3839 Acc: 0.8980
# Epoch 9/24
#  train Loss: 0.6390 Acc: 0.7959 	 valid Loss: 0.4283 Acc: 0.8776
# Epoch 10/24
#  train Loss: 0.9620 Acc: 0.7551 	 valid Loss: 0.5029 Acc: 0.8367
# Epoch 11/24
#  train Loss: 0.8044 Acc: 0.7806 	 valid Loss: 0.3004 Acc: 0.8571
# Epoch 12/24
#  train Loss: 0.7875 Acc: 0.8112 	 valid Loss: 0.2622 Acc: 0.9592
# Epoch 13/24
#  train Loss: 1.1900 Acc: 0.7653 	 valid Loss: 0.5706 Acc: 0.8980
# Epoch 14/24
#  train Loss: 0.9685 Acc: 0.7653 	 valid Loss: 0.4096 Acc: 0.8776
# Epoch 15/24
#  train Loss: 0.7290 Acc: 0.8010 	 valid Loss: 0.2851 Acc: 0.9184
# Epoch 16/24
#  train Loss: 0.8082 Acc: 0.7449 	 valid Loss: 0.3769 Acc: 0.8571
# Epoch 17/24
#  train Loss: 0.5856 Acc: 0.8061 	 valid Loss: 0.2988 Acc: 0.8980
# Epoch 18/24
#  train Loss: 0.6378 Acc: 0.7806 	 valid Loss: 0.1978 Acc: 0.9184
# Epoch 19/24
#  train Loss: 0.7056 Acc: 0.7959 	 valid Loss: 0.2562 Acc: 0.8776
# Epoch 20/24
#  train Loss: 0.4253 Acc: 0.8418 	 valid Loss: 0.4168 Acc: 0.8980
# Epoch 21/24
#  train Loss: 0.3796 Acc: 0.8827 	 valid Loss: 0.2718 Acc: 0.8980
# Epoch 22/24
#  train Loss: 0.8049 Acc: 0.7755 	 valid Loss: 0.5560 Acc: 0.8571
# Epoch 23/24
#  train Loss: 0.8606 Acc: 0.7908 	 valid Loss: 0.2685 Acc: 0.8571
# Epoch 24/24
#  train Loss: 0.7032 Acc: 0.7908 	 valid Loss: 0.2666 Acc: 0.8980
# Training complete in 1m 35s
# Best val Acc: 0.959184
# -----5-----
# Epoch 0/24
#  train Loss: 0.5150 Acc: 0.8316 	 valid Loss: 0.2757 Acc: 0.9388
# Epoch 1/24
#  train Loss: 0.5398 Acc: 0.8622 	 valid Loss: 0.4744 Acc: 0.8980
# Epoch 2/24
#  train Loss: 0.5804 Acc: 0.8010 	 valid Loss: 0.4268 Acc: 0.8776
# Epoch 3/24
#  train Loss: 0.5426 Acc: 0.8520 	 valid Loss: 0.7451 Acc: 0.8367
# Epoch 4/24
#  train Loss: 0.7148 Acc: 0.8112 	 valid Loss: 0.2817 Acc: 0.9388
# Epoch 5/24
#  train Loss: 0.6506 Acc: 0.8571 	 valid Loss: 0.3566 Acc: 0.8980
# Epoch 6/24
#  train Loss: 0.5923 Acc: 0.8469 	 valid Loss: 0.4155 Acc: 0.8776
# Epoch 7/24
#  train Loss: 0.6759 Acc: 0.8520 	 valid Loss: 0.4368 Acc: 0.8980
# Epoch 8/24
#  train Loss: 0.4954 Acc: 0.8418 	 valid Loss: 0.4503 Acc: 0.9184
# Epoch 9/24
#  train Loss: 0.7188 Acc: 0.8163 	 valid Loss: 0.4159 Acc: 0.8571
# Epoch 10/24
#  train Loss: 0.5190 Acc: 0.8367 	 valid Loss: 0.6386 Acc: 0.8776
# Epoch 11/24
#  train Loss: 0.5640 Acc: 0.8061 	 valid Loss: 0.3398 Acc: 0.8980
# Epoch 12/24
#  train Loss: 0.5492 Acc: 0.8520 	 valid Loss: 0.5747 Acc: 0.8571
# Epoch 13/24
#  train Loss: 0.5379 Acc: 0.8418 	 valid Loss: 0.4959 Acc: 0.8571
# Epoch 14/24
#  train Loss: 0.5751 Acc: 0.8367 	 valid Loss: 0.5659 Acc: 0.8571
# Epoch 15/24
#  train Loss: 0.6299 Acc: 0.8265 	 valid Loss: 0.5855 Acc: 0.7959
# Epoch 16/24
#  train Loss: 0.7050 Acc: 0.8265 	 valid Loss: 0.4363 Acc: 0.8571
# Epoch 17/24
#  train Loss: 0.6640 Acc: 0.8520 	 valid Loss: 0.3356 Acc: 0.8980
# Epoch 18/24
#  train Loss: 0.5959 Acc: 0.8010 	 valid Loss: 0.2912 Acc: 0.8980
# Epoch 19/24
#  train Loss: 0.4956 Acc: 0.8265 	 valid Loss: 0.6028 Acc: 0.8776
# Epoch 20/24
#  train Loss: 0.6987 Acc: 0.8214 	 valid Loss: 0.3600 Acc: 0.8980
# Epoch 21/24
#  train Loss: 0.7299 Acc: 0.7806 	 valid Loss: 0.6645 Acc: 0.8367
# Epoch 22/24
#  train Loss: 0.5071 Acc: 0.8316 	 valid Loss: 0.4288 Acc: 0.8776
# Epoch 23/24
#  train Loss: 0.7613 Acc: 0.8010 	 valid Loss: 0.3681 Acc: 0.8571
# Epoch 24/24
#  train Loss: 0.5756 Acc: 0.8367 	 valid Loss: 0.3502 Acc: 0.8980
# Training complete in 1m 36s
# Best val Acc: 0.938776

# %%
# Validation 
print('VGG16 Result')
print(f'Validation Accuracy: 平均 {np.mean(scores)*100:.1f} 標準偏差 {np.std(cores)*100:.4f}')

# Test
print('Test results:')
print(class_names)

tmp_list = [] # Accuracy
print('Accuracy:', end='\t')
for i in range(class_num):
    tmp_list = [r[i] for r in test_accuracy]
    means = np.mean(tmp_list)
    stds = np.std(tmp_list)
    print(f'{np.mean(tmp_list):.1f}±{np.std(tmp_list):.2f}', end='\t')

tmp_list = [] # Precision
print('\nPrecision:', end='\t')
for i in range(class_num):
    tmp_list = [r[i] for r in test_precision]
    means = np.mean(tmp_list)
    stds = np.std(tmp_list)
    print(f'{np.mean(tmp_list):.1f}±{np.std(tmp_list):.2f}', end='\t')

tmp_list = [] # Recall
print('\nRecall:', end='\t')
for i in range(class_num):
    tmp_list = [r[i] for r in test_recall]
    means = np.mean(tmp_list)
    stds = np.std(tmp_list)
    print(f'{np.mean(tmp_list):.1f}±{np.std(tmp_list):.2f}', end='\t')

print('\nConf Matrix:') # 混同行列
for i in range(class_num):
    print([r[i] for r in conf_mat])
# Out:
# VGG16 Result
# Validation Accuracy: 平均 93.9 分散 0.1166
# Test results:
# ['1Sputter', '2Fiber', '3Block', '4Bar', '5AGFragment']
# Accuracy:	98.9±0.71	96.0±1.52	99.0±0.60	98.5±0.47	93.9±0.97
# Precision:	97.1±3.81	99.0±1.90	96.2±3.56	98.1±2.33	75.2±3.56
# Recall:	97.2±2.26	84.2±4.86	99.1±1.82	94.5±1.62	93.1±4.29
# Conf Matrix:
# [array([20,  1,  0,  0,  0]), array([21,  0,  0,  0,  0]), array([19,  2,  0,  0,  0]), array([21,  0,  0,  0,  0]), array([21,  0,  0,  0,  0])]
# [array([ 0, 21,  0,  0,  0]), array([ 0, 21,  0,  0,  0]), array([ 0, 21,  0,  0,  0]), array([ 0, 21,  0,  0,  0]), array([ 0, 20,  0,  1,  0])]
# [array([ 0,  0, 21,  0,  0]), array([ 0,  0, 21,  0,  0]), array([ 0,  0, 20,  0,  1]), array([ 0,  0, 19,  0,  2]), array([ 0,  0, 20,  0,  1])]
# [array([ 0,  0,  0, 20,  1]), array([ 0,  0,  0, 21,  0]), array([ 0,  0,  0, 20,  1]), array([ 0,  0,  0, 21,  0]), array([ 0,  0,  0, 21,  0])]
# [array([ 1,  2,  0,  1, 17]), array([ 1,  3,  1,  1, 15]), array([ 0,  5,  0,  1, 15]), array([ 1,  3,  0,  1, 16]), array([ 0,  4,  0,  1, 16])]

# %%
PATH = '/content/drive/MyDrive/Tanpopo/model_vgg16_weights.pth'
#torch.save(model_vgg16.state_dict(), PATH) # 重みを保存
